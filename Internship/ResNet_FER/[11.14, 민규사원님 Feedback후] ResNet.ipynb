# %% [markdown]
# # gpu 할당
# https://artiiicy.tistory.com/61

# %%
import os

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"  # Arrange GPU devices starting from 0
os.environ["CUDA_VISIBLE_DEVICES"]= "1"  # Set the GPU 2 to use
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print('Device:', device)
print('Current cuda device:', torch.cuda.current_device())
print('Count of using GPUs:', torch.cuda.device_count())
# Out:
# Device: cuda
# Current cuda device: 0
# Count of using GPUs: 2

# %% [markdown]
# # ResNet + tensorboard + torchinfo + Epoch당 걸리는 시간

# %%
import torch.nn as nn
import torch.optim as optim
from resnet import ResNet18, ResNet34, ResNet50, ResNet101, ResNet152
import os
import torchvision.models as models
from skimage import io, transform
from torch.utils.tensorboard import SummaryWriter



import torch.backends.cudnn as cudnn
import torch
import re
import PIL
import numpy as np
from PIL import Image
from torch.utils.data import Dataset, DataLoader
import torchvision
import torchvision.transforms as tr
from matplotlib import pyplot as plt

''' random seed fixed'''
import random

path = "/home/sldev1/Project/hyeongeun_test/data/FER"
torch.manual_seed(0)
torch.cuda.manual_seed(0)
torch.cuda.manual_seed_all(0)
np.random.seed(0)
cudnn.benchmark = False
cudnn.deterministic = True
random.seed(0)

# %%
#Simple Learning Rate Scheduler
def lr_scheduler(optimizer, epoch):
    lr = learning_rate
    if epoch == 50:
        lr /= 2
    if epoch == 100:
        lr /= 2
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# Xavier
def init_weights(m):
    if isinstance(m, nn.Linear):
        torch.nn.init.xavier_uniform(m.weight)
        m.bias.data.fill_(0.01)

# %%
from torch.utils.data import Dataset
import glob


def img_load(img_path):

    jpg = glob.glob(img_path+'*.jpg')
    sort_jpg = sorted(jpg, key=lambda s: int(re.findall(r'\d+', s)[1]))
    #print("img_load def is play")
    return sort_jpg


def label_load(label_path):
    #enumerate #파이썬내장함수.. 강민규사원님은 이걸로 쓰셨는데 느리더래
    label = glob.glob(label_path+'*exp.npy')
    sort_label = sorted(label,key=lambda s: int(re.findall(r'\d+', s)[1]))
    #print("label_load def is play")
    return sort_label
    
    
    
class MyFERDataset(Dataset):
    
    def __init__(self, img_path_base, label_path_base, train=None, transform=None):
        super(MyFERDataset, self).__init__()
        
        if train == True:
            self.img_path = img_path_base+'/train_set/images/'
            self.label_path = label_path_base+'/train_set/annotations/'
        else:
            self.img_path = img_path_base+'/val_set/images/'
            self.label_path = label_path_base+'/val_set/annotations/'

        self.img = img_load(self.img_path)
        self.label = label_load(self.label_path)
        self.transform = transform
        
    
    def __getitem__(self, idx):
        img_read = io.imread(self.img[idx]) 
        label_read = np.load(self.label[idx])
        label_read = label_read.astype(np.int64)
        label_tr = torch.from_numpy(label_read)
        
        
        if self.transform:
            img_tr = self.transform(img_read)
        
        
        return img_tr, label_tr
    

    def __len__(self):
        return len(self.label)
    
    if __name__ == "__main__":
        print('hi, i\'m main')
# Out:
# hi, i'm main

# %%
transform_train = tr.Compose([tr.ToTensor(),
                              tr.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5))])
transform_test = tr.Compose([tr.ToTensor()])


train_dataset = MyFERDataset(img_path_base = path,
                              label_path_base = path,
                              train=True,
                              transform=transform_train)
test_dataset = MyFERDataset(img_path_base = path,
                              label_path_base = path,
                              train=False,
                              transform=transform_test)

# %%
test_dataset[0]
# Out:
# (tensor([[[0.0588, 0.0431, 0.0431,  ..., 0.2078, 0.2196, 0.2588],
#           [0.0588, 0.0471, 0.0471,  ..., 0.2118, 0.2353, 0.2824],
#           [0.0588, 0.0510, 0.0588,  ..., 0.2235, 0.2627, 0.3176],
#           ...,
#           [0.7098, 0.7137, 0.7216,  ..., 0.8118, 0.8196, 0.8275],
#           [0.7176, 0.7216, 0.7294,  ..., 0.8078, 0.8157, 0.8235],
#           [0.7255, 0.7294, 0.7373,  ..., 0.8078, 0.8157, 0.8196]],
#
#          [[0.0549, 0.0392, 0.0392,  ..., 0.1686, 0.1804, 0.2196],
#           [0.0549, 0.0431, 0.0431,  ..., 0.1725, 0.1961, 0.2431],
#           [0.0549, 0.0471, 0.0549,  ..., 0.1725, 0.2118, 0.2667],
#           ...,
#           [0.6667, 0.6706, 0.6784,  ..., 0.8314, 0.8392, 0.8471],
#           [0.6745, 0.6784, 0.6863,  ..., 0.8275, 0.8353, 0.8431],
#           [0.6824, 0.6863, 0.6941,  ..., 0.8275, 0.8353, 0.8392]],
#
#          [[0.0392, 0.0235, 0.0235,  ..., 0.1333, 0.1451, 0.1843],
#           [0.0392, 0.0275, 0.0275,  ..., 0.1373, 0.1608, 0.2078],
#           [0.0392, 0.0314, 0.0392,  ..., 0.1412, 0.1765, 0.2314],
#           ...,
#           [0.7922, 0.7961, 0.8039,  ..., 0.9569, 0.9569, 0.9647],
#           [0.8000, 0.8039, 0.8118,  ..., 0.9529, 0.9529, 0.9608],
#           [0.8078, 0.8118, 0.8196,  ..., 0.9529, 0.9529, 0.9569]]]),
#  tensor(0))

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2)

# %%
dataiter = iter(test_loader)
images, labels = dataiter.next()

# %%
labels.size()
print(images.size())
# Out:
# torch.Size([32, 3, 224, 224])

# %%
print(labels)
# Out:
# tensor([0, 0, 4, 0, 2, 5, 6, 0, 7, 7, 6, 1, 4, 2, 7, 4, 2, 4, 2, 2, 7, 3, 0, 7,
#         1, 3, 2, 5, 7, 2, 7, 3])

# %%
device = 'cuda:1'
model = ResNet50()
# ResNet18, ResNet34, ResNet50, ResNet101, ResNet152 중에 택일하여 사용

# %%
model.apply(init_weights)
model = model.to(device)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.

# %%
learning_rate = 0.001
num_epoch = 200
model_name = 'ResNet_FER_11.14.pth'

loss_fn = nn.CrossEntropyLoss()
# optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0001)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
train_loss = 0
valid_loss = 0
correct = 0
total_cnt = 0
best_acc = 0

# %%
import time
start = time.time() #시작 시간 저장
# Train
writer = SummaryWriter()
for epoch in range(num_epoch):
    
    if epoch == 1:
        start = time.time() #시작 시간 저장
    if epoch == 2:
        epoch_time_for_1 = time.time()-start
        timer = epoch_time_for_1 * num_epoch
        print("학습에 총 걸리는 시간 :", timer)    
    
    

    print(f"====== { epoch+1} epoch of { num_epoch } ======")
    model.train()
    lr_scheduler(optimizer, epoch)
    train_loss = 0
    valid_loss = 0
    correct = 0
    total_cnt = 0
    
    
    
    # Train Phase
    for step, batch in enumerate(train_loader):
        #  input and target
        batch[0], batch[1] = batch[0].to(device), batch[1].to(device)
        optimizer.zero_grad()
        
        logits = model(batch[0]) #ResNet50(batch[0])
        loss = loss_fn(logits, batch[1])
        # loss.backward()
        # optimizer.step()
        
        train_loss += loss.item()
        #_, predict = logits.max(1)
        _, predict = torch.max(logits, dim=1)
        
        total_cnt += batch[1].size(0)
        correct +=  predict.eq(batch[1]).sum().item()
        
        if step % 1000 == 0 and step != 0:
            print(f"\n====== { step } Step of { len(train_loader) } ======")
            print(f"Train Acc : { correct / total_cnt }")
            print(f"Train Loss : { loss.item() / batch[1].size(0) }")
        
        loss.backward()
        optimizer.step()

            
    train_acc_visual = (correct / total_cnt) * 100
    train_loss_visual = train_loss / batch[1].size(0)
    writer.add_scalar('acc/train', train_acc_visual, epoch)
    writer.add_scalar('loss/train', train_loss_visual, epoch)            
            

    correct = 0
    total_cnt = 0
    
# Test Phase
    with torch.no_grad():
        model.eval()
        for step, batch in enumerate(test_loader):
            # input and target
            batch[0], batch[1] = batch[0].to(device), batch[1].to(device)
            total_cnt += batch[1].size(0)
            logits = model(batch[0])
            valid_loss += loss_fn(logits, batch[1])
            _, predict = logits.max(1)
            correct += predict.eq(batch[1]).sum().item()
        valid_acc = correct / total_cnt
        print(f"\nValid Acc : { valid_acc }")    
        print(f"Valid Loss : { valid_loss / total_cnt }")
        
        valid_acc_visual = valid_acc * 100
        valid_loss_visual = valid_loss / total_cnt
        writer.add_scalar('acc/valid', valid_acc_visual, epoch)
        writer.add_scalar('loss/valid', valid_loss_visual, epoch)
        
        

        if(valid_acc > best_acc):
            best_acc = valid_acc
            # torch.save(model, model_name)
            # print("Model Saved!")
            torch.save(model.state_dict(), model_name)
            print('Model Saved!')
# Out:
# ====== 1 epoch of 200 ======
#
# ====== 1000 Step of 8990 ======
# Train Acc : 0.460757992007992
# Train Loss : 0.041193850338459015
#
# ====== 2000 Step of 8990 ======
# Train Acc : 0.511322463768116
# Train Loss : 0.04209895431995392
#
# ====== 3000 Step of 8990 ======
# Train Acc : 0.5450266577807398
# Train Loss : 0.04160279780626297
#
# ====== 4000 Step of 8990 ======
# Train Acc : 0.5680611097225694
# Train Loss : 0.03106488659977913
#
# ====== 5000 Step of 8990 ======
# Train Acc : 0.5849392621475705
# Train Loss : 0.03127160295844078
#
# ====== 6000 Step of 8990 ======
# Train Acc : 0.5980305365772371
# Train Loss : 0.026454444974660873
#
# ====== 7000 Step of 8990 ======
# Train Acc : 0.609198685902014
# Train Loss : 0.024817606434226036
#
# ====== 8000 Step of 8990 ======
# Train Acc : 0.6182039745031871
# Train Loss : 0.02630367875099182
#
# Valid Acc : 0.26481620405101275
# Valid Loss : 0.08026042580604553
# Model Saved!
# ====== 2 epoch of 200 ======
#
# ====== 1000 Step of 8990 ======
# Train Acc : 0.7003621378621379
# Train Loss : 0.01882476732134819
#
# ====== 2000 Step of 8990 ======
# Train Acc : 0.7030391054472763
# Train Loss : 0.02809957042336464
#
# ====== 3000 Step of 8990 ======
# Train Acc : 0.

# ├─Conv2d: 1-1                            [1, 64, 112, 112]         9,472
# ├─BatchNorm2d: 1-2                       [1, 64, 112, 112]         128
# ├─MaxPool2d: 1-3                         [1, 64, 56, 56]           --
# ├─Sequential: 1-4                        [1, 256, 56, 56]          --
# │    └─BottleNeck: 2-1                   [1, 256, 56, 56]          --
# │    │    └─Conv2d: 3-1                  [1, 64, 56, 56]           4,096
# │    │    └─BatchNorm2d: 3-2             [1, 64, 56, 56]           128
# │    │    └─Conv2d: 3-3                  [1, 64, 56, 56]           36,864
# │    │    └─BatchNorm2d: 3-4             [1, 64, 56, 56]           128
# │    │    └─Conv2d: 3-5                  [1, 256, 56, 56]          16,384
# │    │    └─BatchNorm2d: 3-6             [1, 256, 56, 56]          512
# │    │    └─Sequential: 3-7              [1, 256, 56, 56]          16,896
# │    └─BottleNeck: 2-2                   [1, 256, 56, 56]          --
# │    │    └─Conv2d: 3-8                  [1, 64, 56, 56]           16,384
# │    │    └─BatchNorm2d: 3-9             [1, 64, 56, 56]           128
# │    │    └─Conv2d: 3-10                 [1, 64, 56, 56]           36,864
# │    │    └─BatchNorm2d: 3-11            [1, 64, 56, 56]           128
# │    │    └─Conv2d: 3-12                 [1, 256, 56, 56]          16,384
# │    │    └─BatchNorm2d: 3-13            [1, 256, 56, 56]          512
# │    │    └─Sequential: 3-14             [1, 256, 56, 56]          --
# │    └─BottleNeck: 2-3                   [1, 256, 56, 56]          --
# │    │    └─Conv2d: 3-15                 [1, 64, 56, 56]           16,384
# │    │    └─BatchNorm2d: 3-16            [1, 64, 56, 56]           128
# │    │    └─Conv2d: 3-17                 [1, 64, 56, 56]           36,864
# │    │    └─BatchNorm2d: 3-18            [1, 64, 56, 56]           128
# │    │    └─Conv2d: 3-19                 [1, 256, 56, 56]          16,384
# │    │    └─BatchNorm2d: 3-20            [1, 256, 56, 56]          512
# │    │    └─Sequential: 3-21             [1, 256, 56, 56]          --
# ├─Sequential: 1-5                        [1, 512, 28, 28]          --
# │    └─BottleNeck: 2-4                   [1, 512, 28, 28]          --
# │    │    └─Conv2d: 3-22                 [1, 128, 28, 28]          32,768
# │    │    └─BatchNorm2d: 3-23            [1, 128, 28, 28]          256
# │    │    └─Conv2d: 3-24                 [1, 128, 28, 28]          147,456
# │    │    └─BatchNorm2d: 3-25            [1, 128, 28, 28]          256
# │    │    └─Conv2d: 3-26                 [1, 512, 28, 28]          65,536
# │    │    └─BatchNorm2d: 3-27            [1, 512, 28, 28]          1,024
# │    │    └─Sequential: 3-28             [1, 512, 28, 28]          132,096
# │    └─BottleNeck: 2-5                   [1, 512, 28, 28]          --
# │    │    └─Conv2d: 3-29                 [1, 128, 28, 28]          65,536
# │    │    └─BatchNorm2d: 3-30            [1, 128, 28, 28]          256
# │    │    └─Conv2d: 3-31                 [1, 128, 28, 28]          147,456
# │    │    └─BatchNorm2d: 3-32            [1, 128, 28, 28]          256
# │    │    └─Conv2d: 3-33                 [1, 512, 28, 28]          65,536
# │    │    └─BatchNorm2d: 3-34            [1, 512, 28, 28]          1,024
# │    │    └─Sequential: 3-35             [1, 512, 28, 28]          --
# │    └─BottleNeck: 2-6                   [1, 512, 28, 28]          --
# │    │    └─Conv2d: 3-36                 [1, 128, 28, 28]          65,536
# │    │    └─BatchNorm2d: 3-37            [1, 128, 28, 28]          256
# │    │    └─Conv2d: 3-38                 [1, 128, 28, 28]          147,456
# │    │    └─BatchNorm2d: 3-39            [1, 128, 28, 28]          256
# │    │    └─Conv2d: 3-40                 [1, 512, 28, 28]          65,536
# │    │    └─BatchNorm2d: 3-41            [1, 512, 28, 28]          1,024
# │    │    └─Sequential: 3-42             [1, 512, 28, 28]          --
# │    └─BottleNeck: 2-7                   [1, 512, 28, 28]          --
# │    │    └─Conv2d: 3-43                 [1, 128, 28, 28]          65,536
# │    │    └─BatchNorm2d: 3-44            [1, 128, 28, 28]          256
# │    │    └─Conv2d: 3-45                 [1, 128, 28, 28]          147,456
# │    │    └─BatchNorm2d: 3-46            [1, 128, 28, 28]          256
# │    │    └─Conv2d: 3-47                 [1, 512, 28, 28]          65,536
# │    │    └─BatchNorm2d: 3-48            [1, 512, 28, 28]          1,024
# │    │    └─Sequential: 3-49             [1, 512, 28, 28]          --
# ├─Sequential: 1-6                        [1, 1024, 14, 14]         --
# │    └─BottleNeck: 2-8                   [1, 1024, 14, 14]         --
# │    │    └─Conv2d: 3-50                 [1, 256, 14, 14]          131,072
# │    │    └─BatchNorm2d: 3-51            [1, 256, 14, 14]          512
# │    │    └─Conv2d: 3-52                 [1, 256, 14, 14]          589,824
# │    │    └─BatchNorm2d: 3-53            [1, 256, 14, 14]          512
# │    │    └─Conv2d: 3-54                 [1, 1024, 14, 14]         262,144
# │    │    └─BatchNorm2d: 3-55            [1, 1024, 14, 14]         2,048
# │    │    └─Sequential: 3-56             [1, 1024, 14, 14]         526,336
# │    └─BottleNeck: 2-9                   [1, 1024, 14, 14]         --
# │    │    └─Conv2d: 3-57                 [1, 256, 14, 14]          262,144
# │    │    └─BatchNorm2d: 3-58            [1, 256, 14, 14]          512
# │    │    └─Conv2d: 3-59                 [1, 256, 14, 14]          589,824
# │    │    └─BatchNorm2d: 3-60            [1, 256, 14, 14]          512
# │    │    └─Conv2d: 3-61                 [1, 1024, 14, 14]         262,144
# │    │    └─BatchNorm2d: 3-62            [1, 1024, 14, 14]         2,048
# │    │    └─Sequential: 3-63             [1, 1024, 14, 14]         --
# │    └─BottleNeck: 2-10                  [1, 1024, 14, 14]         --
# │    │    └─Conv2d: 3-64                 [1, 256, 14, 14]          262,144
# │    │    └─BatchNorm2d: 3-65            [1, 256, 14, 14]          512
# │    │    └─Conv2d: 3-66                 [1, 256, 14, 14]          589,824
# │    │    └─BatchNorm2d: 3-67            [1, 256, 14, 14]          512
# │    │    └─Conv2d: 3-68                 [1, 1024, 14, 14]         262,144
# │    │    └─BatchNorm2d: 3-69            [1, 1024, 14, 14]         2,048
# │    │    └─Sequential: 3-70             [1, 1024, 14, 14]         --
# │    └─BottleNeck: 2-11                  [1, 1024, 14, 14]         --
# │    │    └─Conv2d: 3-71                 [1, 256, 14, 14]          262,144
# │    │    └─BatchNorm2d: 3-72            [1, 256, 14, 14]          512
# │    │    └─Conv2d: 3-73                 [1, 256, 14, 14]          589,824
# │    │    └─BatchNorm2d: 3-74            [1, 256, 14, 14]          512
# │    │    └─Conv2d: 3-75                 [1, 1024, 14, 14]         262,144
# │    │    └─BatchNorm2d: 3-76            [1, 1024, 14, 14]         2,048
# │    │    └─Sequential: 3-77             [1, 1024, 14, 14]         --
# │    └─BottleNeck: 2-12                  [1, 1024, 14, 14]         --
# │    │    └─Conv2d: 3-78                 [1, 256, 14, 14]          262,144
# │    │    └─BatchNorm2d: 3-79            [1, 256, 14, 14]          512
# │    │    └─Conv2d: 3-80                 [1, 256, 14, 14]          589,824
# │    │    └─BatchNorm2d: 3-81            [1, 256, 14, 14]          512
# │    │    └─Conv2d: 3-82                 [1, 1024, 14, 14]         262,144
# │    │    └─BatchNorm2d: 3-83            [1, 1024, 14, 14]         2,048
# │    │    └─Sequential: 3-84             [1, 1024, 14, 14]         --
# │    └─BottleNeck: 2-13                  [1, 1024, 14, 14]         --
# │    │    └─Conv2d: 3-85                 [1, 256, 14, 14]          262,144
# │    │    └─BatchNorm2d: 3-86            [1, 256, 14, 14]          512
# │    │    └─Conv2d: 3-87                 [1, 256, 14, 14]          589,824
# │    │    └─BatchNorm2d: 3-88            [1, 256, 14, 14]          512
# │    │    └─Conv2d: 3-89                 [1, 1024, 14, 14]         262,144
# │    │    └─BatchNorm2d: 3-90            [1, 1024, 14, 14]         2,048
# │    │    └─Sequential: 3-91             [1, 1024, 14, 14]         --
# ├─Sequential: 1-7                        [1, 2048, 7, 7]           --
# │    └─BottleNeck: 2-14                  [1, 2048, 7, 7]           --
# │    │    └─Conv2d: 3-92                 [1, 512, 7, 7]            524,288
# │    │    └─BatchNorm2d: 3-93            [1, 512, 7, 7]            1,024
# │    │    └─Conv2d: 3-94                 [1, 512, 7, 7]            2,359,296
# │    │    └─BatchNorm2d: 3-95            [1, 512, 7, 7]            1,024
# │    │    └─Conv2d: 3-96                 [1, 2048, 7, 7]           1,048,576
# │    │    └─BatchNorm2d: 3-97            [1, 2048, 7, 7]           4,096
# │    │    └─Sequential: 3-98             [1, 2048, 7, 7]           2,101,248
# │    └─BottleNeck: 2-15                  [1, 2048, 7, 7]           --
# │    │    └─Conv2d: 3-99                 [1, 512, 7, 7]            1,048,576
# │    │    └─BatchNorm2d: 3-100           [1, 512, 7, 7]            1,024
# │    │    └─Conv2d: 3-101                [1, 512, 7, 7]            2,359,296
# │    │    └─BatchNorm2d: 3-102           [1, 512, 7, 7]            1,024
# │    │    └─Conv2d: 3-103                [1, 2048, 7, 7]           1,048,576
# │    │    └─BatchNorm2d: 3-104           [1, 2048, 7, 7]           4,096
# │    │    └─Sequential: 3-105            [1, 2048, 7, 7]           --
# │    └─BottleNeck: 2-16                  [1, 2048, 7, 7]           --
# │    │    └─Conv2d: 3-106                [1, 512, 7, 7]            1,048,576
# │    │    └─BatchNorm2d: 3-107           [1, 512, 7, 7]            1,024
# │    │    └─Conv2d: 3-108                [1, 512, 7, 7]            2,359,296
# │    │    └─BatchNorm2d: 3-109           [1, 512, 7, 7]            1,024
# │    │    └─Conv2d: 3-110                [1, 2048, 7, 7]           1,048,576
# │    │    └─BatchNorm2d: 3-111           [1, 2048, 7, 7]           4,096
# │    │    └─Sequential: 3-112            [1, 2048, 7, 7]           --
# ├─AdaptiveAvgPool2d: 1-8                 [1, 2048, 1, 1]           --
# ├─Linear: 1-9                            [1, 10]                   20,490
# ==========================================================================================
# Total params: 23,528,586
# Trainable params: 23,528,586
# Non-trainable params: 0
# Total mult-adds (G): 3.86
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 169.39
# Params size (MB): 94.11
# Estimated Total Size (MB): 264.11
# ==========================================================================================

# %%
label_tags = {
    0 : 'Neutral',
    1 : 'Happiness', #기쁨
    2 : 'Sadness', #슬픔
    3 : 'Suprise', #놀람
    4 : 'Fear', #
    5 : 'Disgust', #역겨움
    6 : 'Anger', #분노
    7 : 'Content'
}

# %% [markdown]
# - 정보 :
#     1. batch[0] : 이미지
#     2. batch[1] : 라벨

# %%
import gc
import torch

gc.collect()
torch.cuda.empty_cache()

# %%
for step, batch in enumerate(test_loader):
    batch[0], batch[1] = batch[0].to(device), batch[1].to(device)

    logits = model(batch[0])
    #print(batch[0], "\n****************\n", batch[1])
    print("\n******logits*******\n",logits)
    print("\n\n\n******logits_max*******\n",logits.max(1))
    
    _, predict = torch.max(logits, dim=1)
    # _, predict = logits.max()
    print("\n\n***********_____***********\n", _, "\n\n**********predict************\n", predict)
    
    # correct += predict.eq(batch[1]).sum().item()
    # print(correct)


    
    #valid_loss += loss_fn(logits, batch[1])
    #_, predict = logits.max(1)
    #correct += predict.eq(batch[1]).sum().item()
    #print(_,"\n\n\n", predict)
# Out:
# ******logits*******
#  tensor([[ 2.1195,  2.7134,  2.5982, -2.9567, -0.5159, -0.1822,  1.0926, -0.5362,
#          -0.4513,  0.6408],
#         [ 2.7935,  3.1004,  2.8023, -3.0783, -0.2720, -0.3425,  2.2156, -0.8654,
#          -0.2742,  1.2150],
#         [ 2.7593,  3.4954,  2.7906, -2.9082, -0.6154, -0.2392,  1.6464, -0.7873,
#           0.1432,  1.1898],
#         [ 1.8798,  3.4004,  2.7182, -2.5275, -0.2999,  0.0271,  1.9154, -0.8489,
#          -0.0723,  0.5180]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.7134, 3.1004, 3.4954, 3.4004], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.7134, 3.1004, 3.4954, 3.4004], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.8309,  4.2414,  2.9858, -3.4669, -0.0742, -0.1062,  3.0931, -1.6901,
#           0.1618,  1.5397],
#         [ 2.1942,  2.3570,  2.3450, -2.1711, -0.4142, -0.2287,  0.6796,  0.2760,
#          -0.2474,  0.6186],
#         [ 2.2177,  3.4582,  2.8957, -2.9028, -0.4905, -0.4109,  2.2935, -1.6030,
#          -0.0189,  0.7142],
#         [ 1.9777,  2.1089,  2.3250, -2.5011, -0.8365, -0.2582,  0.4363,  0.3647,
#          -0.4647,  0.6356]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([4.2414, 2.3570, 3.4582, 2.3250], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 1, 2], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([4.2414, 2.3570, 3.4582, 2.3250], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 1, 2], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.1983,  2.7319,  2.6332, -2.5130, -0.7928, -0.0695,  0.7438, -0.4006,
#          -0.3333,  0.6541],
#         [ 2.0120,  3.0341,  2.5036, -2.8335, -0.5354, -0.2299,  1.8370, -0.7779,
#          -0.2045,  0.9135],
#         [ 2.8662,  4.1371,  3.4616, -3.2782,  0.1659, -0.3604,  3.0782, -1.8972,
#          -0.0615,  1.5958],
#         [ 2.4154,  2.6300,  2.2532, -2.4975, -0.6889, -0.2365,  1.1269, -0.3514,
#          -0.4923,  0.4668]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.7319, 3.0341, 4.1371, 2.6300], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.7319, 3.0341, 4.1371, 2.6300], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.5743,  3.8007,  2.9882, -3.0304, -0.3981, -0.2752,  2.5133, -1.8428,
#          -0.0446,  0.9549],
#         [ 2.3797,  2.5505,  2.4254, -2.2959, -0.8174, -0.3859,  1.1768, -0.2321,
#          -0.2352,  0.9321],
#         [ 2.3531,  3.3415,  2.7427, -3.2947, -0.4565, -0.3271,  2.2695, -1.0983,
#          -0.1372,  1.0243],
#         [ 2.0721,  2.6970,  2.5218, -2.6958, -0.6023, -0.0540,  0.8902, -0.2133,
#          -0.3889,  0.6008]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([3.8007, 2.5505, 3.3415, 2.6970], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([3.8007, 2.5505, 3.3415, 2.6970], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.3886,  2.9377,  2.9802, -2.8749, -0.3925, -0.3604,  1.2318, -0.7082,
#          -0.2407,  0.6794],
#         [ 2.6639,  4.5737,  2.4953, -3.2829, -0.4571, -0.0942,  3.4789, -2.0374,
#           0.1658,  1.6963],
#         [ 2.6054,  2.5378,  2.7209, -2.8385, -0.6307, -0.2169,  1.0543,  0.0898,
#          -0.7019,  0.6457],
#         [ 2.0003,  2.4021,  2.5925, -2.7339, -0.5635, -0.3807,  0.8085, -0.2372,
#          -0.4974,  0.3999]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.9802, 4.5737, 2.7209, 2.5925], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([2, 1, 2, 2], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.9802, 4.5737, 2.7209, 2.5925], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([2, 1, 2, 2], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.1640,  2.4139,  2.6437, -2.4278, -0.6669, -0.2714,  0.5111, -0.1199,
#          -0.5131,  0.6683],
#         [ 2.4451,  2.6276,  2.5890, -2.5542, -0.7929, -0.2297,  0.9620,  0.0140,
#          -0.4990,  0.6673],
#         [ 2.5357,  3.5440,  2.9456, -3.1426, -0.4211, -0.0602,  2.4309, -1.1972,
#           0.2535,  1.2145],
#         [ 2.3453,  4.0382,  2.7180, -3.1272, -0.0805, -0.1233,  2.7917, -1.8294,
#          -0.2082,  1.0745]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.6437, 2.6276, 3.5440, 4.0382], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([2, 1, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.6437, 2.6276, 3.5440, 4.0382], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([2, 1, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.2126,  2.5766,  2.3961, -2.5013, -0.6485, -0.1728,  1.5578, -0.5261,
#          -0.4191,  0.9731],
#         [ 2.1230,  4.7385,  3.4646, -3.8434, -0.0065, -0.1025,  3.1228, -2.0279,
#           0.2250,  1.3065],
#         [ 2.4194,  2.4249,  2.3687, -2.4747, -0.4829, -0.1505,  1.3955, -0.1724,
#          -0.4227,  0.6282],
#         [ 2.1916,  2.0010,  2.1204, -2.2791, -0.5783, -0.2309,  0.7002,  0.2008,
#          -0.4702,  0.4179]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.5766, 4.7385, 2.4249, 2.1916], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 1, 0], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.5766, 4.7385, 2.4249, 2.1916], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 1, 0], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.5585,  2.5987,  2.8739, -2.8481, -0.7633, -0.3258,  0.8943, -0.2441,
#          -0.4752,  0.7878],
#         [ 2.6758,  3.3169,  2.4723, -2.8079, -0.4812, -0.5345,  1.9572, -1.0092,
#          -0.1580,  1.1562],
#         [ 2.3254,  3.9428,  3.2782, -3.1947, -0.0220, -0.1153,  2.8143, -1.5613,
#          -0.3541,  1.0682],
#         [ 2.0485,  2.8471,  2.3665, -2.6707, -0.3383, -0.2479,  1.1557, -0.2969,
#          -0.3259,  0.5102]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.8739, 3.3169, 3.9428, 2.8471], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([2, 1, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.8739, 3.3169, 3.9428, 2.8471], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([2, 1, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.1520,  3.0963,  2.6586, -2.4723, -0.5102, -0.2409,  1.3540, -0.5744,
#          -0.5789,  0.4028],
#         [ 2.6113,  3.8876,  3.1946, -3.1310,  0.6017,  0.0226,  2.5149, -1.5728,
#           0.1096,  1.0716],
#         [ 2.3160,  2.6798,  2.5753, -2.6341, -0.9624, -0.1697,  1.3730, -0.5045,
#          -0.2981,  0.8241],
#         [ 2.2361,  2.9578,  2.5490, -2.8847, -0.9669, -0.3679,  1.5191, -0.4002,
#           0.0311,  0.8801]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([3.0963, 3.8876, 2.6798, 2.9578], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([3.0963, 3.8876, 2.6798, 2.9578], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.
], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.5789, 3.9700, 2.6915, 3.7200], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([2, 1, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.5789, 3.9700, 2.6915, 3.7200], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([2, 1, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.3011,  2.4572,  2.2491, -2.3309, -0.9061, -0.4698,  1.0056,  0.3307,
#          -0.7298,  0.6813],
#         [ 2.1874,  2.6555,  2.5434, -2.2762, -0.3016,  0.0270,  0.7937, -0.2180,
#          -0.5242,  0.5052],
#         [ 2.7995,  5.1556,  3.4998, -3.7303, -0.4416, -0.1145,  3.9409, -2.6093,
#           0.6576,  1.6864],
#         [ 1.9458,  2.2321,  2.0455, -2.5332, -0.3870, -0.1273,  0.8162, -0.3061,
#          -0.4517,  0.2238]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.4572, 2.6555, 5.1556, 2.2321], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.4572, 2.6555, 5.1556, 2.2321], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.5564,  3.5482,  2.8489, -2.7819, -0.2737, -0.0776,  2.6220, -1.7102,
#           0.0258,  1.1251],
#         [ 2.3993,  3.5979,  2.9542, -2.8305, -0.5682, -0.5180,  2.6081, -1.1601,
#           0.0370,  0.9280],
#         [ 2.1938,  2.2934,  2.8782, -2.5762, -0.5659, -0.1929,  0.6920,  0.5364,
#          -0.6120,  0.6880],
#         [ 2.5234,  3.0151,  2.5014, -2.8778, -0.6219, -0.1725,  1.3793, -0.9689,
#          -0.2022,  0.7415]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([3.5482, 3.5979, 2.8782, 3.0151], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 2, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([3.5482, 3.5979, 2.8782, 3.0151], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 2, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.7194,  3.6454,  2.6525, -3.1115, -0.4038, -0.3754,  2.0004, -1.2324,
#          -0.0506,  1.4035],
#         [ 2.1730,  2.0018,  2.6477, -2.3873, -0.5343, -0.1023,  0.9829, -0.0438,
#          -0.4887,  0.4518],
#         [ 2.3570,  2.3116,  2.4293, -2.5127, -0.5204, -0.1953,  0.6947,  0.4415,
#          -0.8343,  0.6932],
#         [ 2.2595,  4.3348,  2.9043, -3.2226, -0.0430,  0.0255,  3.1834, -2.2713,
#           0.7051,  1.0110]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([3.6454, 2.6477, 2.4293, 4.3348], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 2, 2, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([3.6454, 2.6477, 2.4293, 4.3348], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 2, 2, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.4169,  3.1361,  3.0396, -2.9427, -0.5460, -0.1371,  1.4551, -0.8571,
#          -0.1020,  0.8121],
#         [ 2.2615,  2.4150,  2.7587, -2.7457, -0.4939, -0.1167,  1.1662, -0.3509,
#          -0.3082,  0.3475],
#         [ 2.3607,  2.5663,  2.4366, -2.6029, -0.5328, -0.2381,  0.9105, -0.0348,
#          -0.3214,  1.1107],
#         [ 2.4278,  4.4568,  2.6696, -3.2496, -0.1560, -0.5202,  3.3983, -1.5480,
#          -0.1613,  1.3823]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([3.1361, 2.7587, 2.5663, 4.4568], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 2, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([3.1361, 2.7587, 2.5663, 4.4568], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 2, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.
device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 2, 2, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.7509,  3.4475,  2.8325, -2.8021, -0.6407, -0.0968,  2.0070, -0.7919,
#           0.3125,  1.0612],
#         [ 2.3752,  4.1389,  2.8367, -3.2879, -0.0610, -0.3256,  3.0603, -1.6332,
#          -0.2751,  0.9642],
#         [ 2.1694,  2.7700,  2.7213, -2.7378, -0.8761, -0.0344,  0.9622, -0.3135,
#          -0.1868,  0.5221],
#         [ 2.3423,  2.4221,  2.6068, -2.6011, -0.5697, -0.4547,  0.8539, -0.1003,
#          -0.7786,  0.9812]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([3.4475, 4.1389, 2.7700, 2.6068], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 1, 2], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([3.4475, 4.1389, 2.7700, 2.6068], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 1, 2], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.0794,  2.5892,  2.5837, -2.5970, -0.7925, -0.0469,  0.9229,  0.2580,
#          -0.3310,  0.8071],
#         [ 2.2912,  2.3452,  2.4115, -2.1137, -0.8520, -0.1436,  1.1020, -0.1620,
#          -0.3146,  0.4891],
#         [ 2.0831,  2.2426,  2.5437, -2.3278, -0.4347, -0.0789,  0.3636,  0.1467,
#          -0.6190,  0.5850],
#         [ 2.6596,  5.0513,  3.3167, -4.3048, -0.2610, -0.3755,  4.4405, -2.6561,
#           0.2733,  1.3906]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.5892, 2.4115, 2.5437, 5.0513], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 2, 2, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.5892, 2.4115, 2.5437, 5.0513], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 2, 2, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.5975,  2.3403,  2.2193, -2.7045, -0.4495, -0.6577,  0.8326, -0.0999,
#          -0.3440,  0.8974],
#         [ 2.8082,  4.9682,  3.1610, -3.3449,  0.0232,  0.1408,  3.7030, -2.1978,
#           0.4252,  1.2105],
#         [ 2.0839,  2.4876,  2.5707, -2.4336, -0.6103, -0.1528,  0.6690,  0.1245,
#          -0.9024,  0.4282],
#         [ 2.0701,  2.6313,  2.7818, -2.6690, -0.6132, -0.0967,  1.7434, -0.4871,
#          -0.1136,  1.0725]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.5975, 4.9682, 2.5707, 2.7818], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([0, 1, 2, 2], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.5975, 4.9682, 2.5707, 2.7818], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([0, 1, 2, 2], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.2737,  2.2934,  2.3630, -2.1156, -0.7233, -0.0986,  0.6864,  0.1664,
#          -0.4529,  0.6315],
#         [ 2.7105,  4.1801,  3.3398, -3.7053, -0.2997, -0.4784,  2.3045, -1.9582,
#          -0.2012,  1.8318],
#         [ 2.1331,  2.4786,  2.1961, -2.5432, -0.2732, -0.1554,  1.2544, -0.6073,
#          -0.1432,  0.5214],
#         [ 2.4094,  2.8466,  2.5805, -2.3703, -0.7091,  0.0982,  2.0074, -0.5105,
#           0.0128,  0.5434]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.3630, 4.1801, 2.4786, 2.8466], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([2, 1, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.3630, 4.1801, 2.4786, 2.8466], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([2, 1, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.2942,  3.2884,  2.7283, -2.6316,  0.0736, -0.2380,  1.9678, -1.0874,
#           0.2876,  1.1097],
#         [ 2.6169,  4.1843,  3.3351, -3.3383, -0.3387, -0.0990,  2.6532, -1.4915,
#          -0.0649,  1.3977],
#         [ 2.1302,  2.4060,  2.4081, -2.5386, -0.7428, -0.0467,  0.8402, -0.0970,
#          -0.3863,  0.7427],
#         [ 2.2818,  2.3365,  2.2912, -2.6370, -0.8922, -0.1821,  1.1728,  0.0412,
#          -0.6243,  0.4508]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([3
device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([2, 1, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.3023,  2.5755,  2.7439, -2.6041, -0.5175, -0.3161,  1.0812, -0.0468,
#          -0.4595,  0.9655],
#         [ 2.2045,  3.0405,  2.3172, -2.7994, -0.6847, -0.3792,  1.5393, -0.2172,
#          -0.3297,  0.7429],
#         [ 2.4363,  3.9409,  3.1274, -3.3817, -0.3820, -0.2453,  2.5839, -1.6319,
#           0.0988,  1.4836],
#         [ 2.5551,  2.9580,  2.5125, -2.2261, -0.4786, -0.0581,  1.6021, -0.6744,
#          -0.2929,  0.5726]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.7439, 3.0405, 3.9409, 2.9580], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([2, 1, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.7439, 3.0405, 3.9409, 2.9580], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([2, 1, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.3533,  2.4153,  2.6526, -2.8038, -0.4199, -0.2147,  0.6800, -0.1603,
#          -0.1069,  0.6597],
#         [ 2.2899,  4.0544,  3.0646, -2.9471, -0.6946,  0.1821,  2.8046, -1.1805,
#          -0.1231,  1.1790],
#         [ 2.2965,  3.3767,  2.4203, -2.7457, -0.4312,  0.0410,  2.0862, -0.7875,
#          -0.2067,  1.0391],
#         [ 2.5353,  2.5739,  2.6803, -2.9420, -0.5218, -0.6783,  1.3355, -0.7858,
#          -0.6625,  0.9242]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.6526, 4.0544, 3.3767, 2.6803], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([2, 1, 1, 2], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.6526, 4.0544, 3.3767, 2.6803], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([2, 1, 1, 2], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.3337,  2.7149,  2.2590, -2.4446, -0.3842, -0.1614,  1.1518, -0.1883,
#          -0.5288,  0.5439],
#         [ 2.3807,  3.7447,  3.2633, -3.2234, -0.2321, -0.1235,  2.7702, -1.4501,
#          -0.2717,  0.9557],
#         [ 2.6420,  3.0714,  3.0026, -2.9391, -0.3721, -0.4136,  1.4207, -0.7518,
#          -0.0673,  1.2873],
#         [ 2.4970,  3.1068,  2.5626, -2.9713, -0.8597, -0.2761,  1.5749, -0.6975,
#          -0.1688,  0.7985]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.7149, 3.7447, 3.0714, 3.1068], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.7149, 3.7447, 3.0714, 3.1068], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.0512,  2.1407,  2.5083, -2.3659, -0.6149, -0.1847,  0.4765, -0.1047,
#          -0.4469,  0.5656],
#         [ 2.4169,  3.1410,  2.7726, -2.5940, -0.2857, -0.3940,  1.5936, -0.7343,
#          -0.2565,  0.8404],
#         [ 2.4260,  2.7814,  2.4885, -2.4005, -0.7515,  0.0875,  1.0647, -0.4270,
#          -0.3189,  0.8676],
#         [ 2.8776,  4.4945,  2.9787, -3.9155, -0.3348, -0.5650,  3.7351, -1.9107,
#           0.1437,  1.3286]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.5083, 3.1410, 2.7814, 4.4945], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([2, 1, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.5083, 3.1410, 2.7814, 4.4945], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([2, 1, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.5344,  4.4211,  3.3061, -3.0882, -0.1165,  0.0149,  2.8766, -1.7656,
#          -0.1754,  1.4575],
#         [ 2.1428,  2.4512,  2.6435, -2.7530, -0.3798, -0.3496,  1.3778, -0.3519,
#          -0.2869,  0.7915],
#         [ 1.8984,  2.7332,  2.4414, -2.4477, -0.5534, -0.2198,  1.2210, -0.1669,
#          -0.0637,  0.8051],
#         [ 2.1435,  2.6602,  1.9017, -2.6242, -0.5972, -0.0624,  1.0659, -0.3580,
#          -0.3108,  0.4824]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([4.4211, 2.6435, 2.7332, 2.6602], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 2, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([4.4211, 2.6435, 2.7332, 2.6602], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 2, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.6578,  3.3234,  2.3136, -2.6997, -0.2397, -0.6347,  1.5720, -0.9738,
#           0.0038,  0.8798],
#         [ 2.4853,  3.2257,  2.9351, -2.6537, -0.3647,  0.2982,  2.2062, -0.8316,
#          -0.0082,  0.8779],
#         [ 2.3268,  3.7530,  2.7802, -3.1274, -0.4224, -0.4027,  1.9793, -0.9786,
#          -0.2603,  1.0808],
#         [ 2.2416,  2.3824,  2.6639, -2.6522, -1.0050,  0.2850,  0.9410, -0.1498,
#          -0.5498,  0.7200]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([3.3234, 3.2257, 3.7530, 2.6639], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 1, 2], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([3.3234, 3.2257, 3.7530, 2.6639], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 1, 2], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.4940,  4.4037,  3.0783, -3.2701,  0.0127, -0.3875,  2.4934, -1.9015,
#           0.3434,  1.3283],
#         [ 2.6220,  2.1159,  2.5464, -2.5771, -0.8141, -0.1856,  0.6426, -0.0413,
#          -0.7559,  0.6375],
#         [ 1.8533,  2.1823,  2.2066, -2.2840, -0.4752, -0.1702,  1.0378, -0.0421,
#          -0.2681,  0.4046],
#         [ 2.3846,  3.5350,  2.9474, -3.0134, -0.6004, -0.1031,  2.5310, -0.9365,
#          -0.1371,  1.1514]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([4.4037, 2.6220, 2.2066, 3.5350], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 0, 2, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([4.4037, 2.6220, 2.2066, 3.5350], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 0, 2, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.5013,  2.6330,  2.7471, -2.4141, -0.9960, -0.3996,  1.0224, -0.3138,
#          -0.3589,  0.5938],
#         [ 2.5950,  3.9760,  2.5569, -3.6154,  0.0866,  0.0291,  1.8986, -0.9382,
#           0.3081,  0.8802],
#         [ 2.0965,  2.4620,  2.6881, -2.2174, -0.7328, -0.0702,  1.3036, -0.6989,
#          -0.5519,  1.0121],
#         [ 2.5100,  3.5443,  2.9401, -3.0404, -0.3004, -0.4582,  2.4330, -1.1437,
#          -0.1112,  1.0458]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.7471, 3.9760, 2.6881, 3.5443], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([2, 1, 2, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.7471, 3.9760, 2.6881, 3.5443], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([2, 1, 2, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.4861,  2.3617,  2.5655, -2.5832, -0.7310,  0.0836,  0.8384,  0.2324,
#          -0.5303,  0.3375],
#         [ 2.2806,  3.1695,  2.8722, -2.8104, -0.0638, -0.4808,  2.3738, -1.0659,
#          -0.0646,  0.9693],
#         [ 2.6411,  3.4259,  2.7145, -2.7807, -0.5141, -0.4363,  1.9371, -0.7895,
#          -0.3659,  0.8148],
#         [ 2.2200,  3.6680,  2.9478, -3.0636, -0.4685, -0.2955,  1.8969, -1.3992,
#          -0.2559,  1.3934]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.5655, 3.1695, 3.4259, 3.6680], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([2, 1, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.5655, 3.1695, 3.4259, 3.6680], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([2, 1, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.9003,  4.6778,  3.2848, -3.4673, -0.2796, -0.2367,  3.7126, -2.1943,
#           0.4816,  1.5840],
#         [ 1.9754,  2.8441,  2.4896, -2.5147, -0.5507, -0.1140,  1.0391, -0.2133,
#          -0.7546,  0.3921],
#         [ 2.1578,  2.3355,  2.4479, -2.5119, -0.2795, -0.3455,  0.8862,  0.1374,
#          -0.4756,  0.3824],
#         [ 2.4196,  2.3003,  2.0971, -2.6623, -0.3295, -0.0577,  0.9870, -0.4644,
#          -0.4528,  0.5597]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([4.6778, 2.8441, 2.4479, 2.4196], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 2, 0], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([4.6778, 2.8441, 2.4479, 2.4196], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 2, 0], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.1485,  2.1960,  2.3163, -2.8092, -0.7176, -0.2565,  0.6428, -0.0847,
#          -0.2388,  0.3475],
#         [ 2.1152,  2.2312,  2.3987, -2.4781, -0.3022, -0.2426,  0.7545, -0.0836,
#          -0.5761,  0.7217],
#         [ 2.6961,  4.3199,  3.1342, -3.3453, -0.1246, -0.3303,  3.1563, -0.9964,
#          -0.0898,  1.6767],
#         [ 2.2225,  3.6866,  2.7916, -2.7634, -0.7098,  0.2427,  1.9548, -1.6795,
#           0.1523,  0.6963]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.3163, 2.3987, 4.3199, 3.6866], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([2, 2, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.3163, 2.3987, 4.3199, 3.6866], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([2, 2, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.4520,  4.0833,  3.2168, -3.1334, -0.4582, -0.6772,  2.8900, -1.3841,
#          -0.0050,  1.4740],
#         [ 2.2997,  3.6962,  2.6676, -3.1751, -0.6852,  0.1123,  1.8865, -1.4409,
#           0.1096,  0.9372],
#         [ 2.4646,  2.5250,  2.7904, -2.4024, -0.4638, -0.0150,  1.2408, -0.3304,
#          -0.2643,  0.7308],
#         [ 2.2145,  2.3339,  2.3534, -2.4278, -0.4988, -0.2494,  0.7934,  0.1332,
#          -0.6561,  0.4577]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([4.0833, 3.6962, 2.7904, 2.3534], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 2, 2], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([4.0833, 3.6962, 2.7904, 2.3534], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 2, 2], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.0221,  2.2302,  2.5389, -2.6766, -0.9219, -0.2517,  0.8491,  0.3062,
#          -0.5517,  0.7903],
#         [ 2.6637,  3.1077,  2.8510, -3.0074, -0.3040, -0.3775,  1.3435, -0.7197,
#          -0.2113,  0.5310],
#         [ 3.0225,  3.8004,  2.9599, -3.1291, -0.5095, -0.2211,  2.0783, -1.4554,
#          -0.3438,  1.3686],
#         [ 2.0858,  3.6367,  2.5665, -2.6324, -0.4408,  0.0563,  2.4492, -1.1434,
#           0.0795,  0.7435]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.5389, 3.1077, 3.8004, 3.6367], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([2, 1, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.5389, 3.1077, 3.8004, 3.6367], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([2, 1, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.2570,  2.2802,  2.6055, -2.6465, -0.5265, -0.3375,  1.1732, -0.4047,
#          -0.4062,  0.8200],
#         [ 2.3257,  2.8923,  2.5428, -2.4782, -0.2785, -0.2133,  1.2833, -0.6099,
#          -0.3207,  0.9286],
#         [ 2.6265,  3.1771,  2.5125, -3.0727, -0.9665,  0.1124,  1.4549, -0.7300,
#          -0.5640,  0.5557],
#         [ 2.4488,  4.1923,  3.0701, -3.0674, -0.3665, -0.5557,  2.4427, -1.3352,
#           0.0834,  1.3085]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.6055, 2.8923, 3.1771, 4.1923], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([2, 1, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.6055, 2.8923, 3.1771, 4.1923], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([2, 1, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.2098,  2.6085,  2.4139, -2.6134, -0.3661,  0.0773,  1.2220, -0.2405,
#          -0.1530,  0.6042],
#         [ 2.3526,  2.2135,  2.5262, -2.2778, -0.6372, -0.1933,  0.9394,  0.0998,
#          -0.5110,  0.6747],
#         [ 1.9776,  2.1296,  2.4387, -1.9494, -0.5371, -0.1878,  0.9271, -0.3319,
#          -0.5247,  0.1854],
#         [ 2.3664,  5.0272,  3.2604, -3.8437, -0.3745, -0.3027,  3.1412, -2.2527,
#           0.1817,  1.8401]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.6085, 2.5262, 2.4387, 5.0272], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 2, 2, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.6085, 2.5262, 2.4387, 5.0272], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 2, 2, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.4661,  4.1780,  2.9710, -3.2667, -0.5582, -0.0664,  2.1738, -1.8237,
#           0.2275,  0.9262],
#         [ 2.3616,  3.2159,  2.5066, -2.6630, -0.2438, -0.3519,  2.2481, -0.8999,
#          -0.1148,  0.8165],
#         [ 2.0085,  2.5114,  2.3141, -2.7079, -0.8457, -0.2875,  0.9284, -0.0390,
#          -0.3613,  0.5465],
#         [ 2.7336,  2.7733,  2.8695, -2.7191, -0.6512, -0.2653,  1.3694, -0.2771,
#          -0.4441,  0.9000]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([4.1780, 3.2159, 2.5114, 2.8695], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 1, 2], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([4.1780, 3.2159, 2.5114, 2.8695], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 1, 2], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.4612,  3.1728,  2.7015, -3.0174, -0.6090, -0.0396,  1.4931, -0.4266,
#          -0.1824,  0.8589],
#         [ 2.4873,  3.2221,  2.6754, -2.8681, -0.5721, -0.1943,  1.7013, -0.8759,
#          -0.2959,  0.5227],
#         [ 2.3978,  3.1990,  2.4411, -2.6299, -0.5965, -0.5109,  1.7906, -0.7204,
#          -0.2159,  1.0721],
#         [ 2.3486,  3.5455,  3.1467, -3.0844, -0.3988, -0.1757,  1.9487, -1.1092,
#          -0.5785,  1.0253]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([3.1728, 3.2221, 3.1990, 3.5455], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([3.1728, 3.2221, 3.1990, 3.5455], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 1, 1], device='cuda:0')
#
# ******logits*******
# ...
#
# ******logits*******
#  tensor([[ 2.1319,  2.4271,  2.4029, -2.2225, -0.5815, -0.3571,  1.0343, -0.0857,
#          -0.7025,  0.3610],
#         [ 1.8897,  1.9279,  2.3057, -2.1756, -0.4727, -0.2919,  0.4626,  0.0994,
#          -0.5113,  0.5979],
#         [ 2.5638,  2.6080,  2.4966, -2.5978, -0.5526, -0.3562,  1.0576, -0.1278,
#          -0.1365,  0.5183],
#         [ 2.3672,  4.9737,  3.2801, -3.7632, -0.0970,  0.1661,  3.9657, -2.6973,
#           0.6415,  1.8413]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.4271, 2.3057, 2.6080, 4.9737], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 2, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.4271, 2.3057, 2.6080, 4.9737], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 2, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.2710,  3.8398,  2.7324, -2.9136, -0.1949, -0.2154,  2.3701, -1.3252,
#           0.0153,  1.1357],
#         [ 2.3104,  2.6049,  2.4458, -2.8459, -0.3707, -0.0943,  1.1409, -0.3954,
#          -0.2362,  0.9688],
#         [ 2.2951,  2.6859,  2.7034, -2.6212, -0.4708, -0.1484,  1.2390,  0.1211,
#          -0.6893,  0.5780],
#         [ 2.5318,  3.5157,  2.7402, -2.9827, -0.6844, -0.2487,  2.1294, -1.5152,
#          -0.1143,  0.9440]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([3.8398, 2.6049, 2.7034, 3.5157], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 2, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([3.8398, 2.6049, 2.7034, 3.5157], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 2, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.4696,  4.0716,  2.6729, -2.8390, -0.3244, -0.2890,  2.5078, -1.2598,
#           0.1013,  1.3841],
#         [ 2.2385,  3.1554,  2.7895, -2.8724, -0.3508, -0.2322,  1.7695, -0.8721,
#           0.2592,  0.9065],
#         [ 2.1668,  2.8371,  2.8679, -2.7945, -0.6947, -0.4169,  0.9268, -0.1459,
#          -0.7942,  0.2125],
#         [ 2.6890,  2.8431,  2.4769, -2.7922, -0.2954, -0.0646,  1.6872, -0.5297,
#          -0.4908,  0.7351]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([4.0716, 3.1554, 2.8679, 2.8431], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 2, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([4.0716, 3.1554, 2.8679, 2.8431], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 2, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.7107,  3.6908,  2.8407, -2.8774, -0.5370, -0.0297,  2.0055, -0.9581,
#          -0.0652,  1.2018],
#         [ 2.1226,  3.3041,  2.5839, -2.8457, -0.5538, -0.3495,  1.5362, -0.9669,
#          -0.4439,  0.7965],
#         [ 2.5954,  3.3117,  2.7216, -2.9115, -0.4994, -0.2977,  1.6973, -0.4185,
#          -0.3995,  0.7645],
#         [ 2.4517,  2.6657,  2.8763, -2.7415, -0.7133, -0.2387,  1.5919, -0.6264,
#          -0.3311,  0.8418]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([3.6908, 3.3041, 3.3117, 2.8763], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 1, 2], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([3.6908, 3.3041, 3.3117, 2.8763], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 1, 2], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.3441,  3.4315,  2.7338, -3.2193, -0.4874, -0.1376,  1.6436, -1.3070,
#           0.1267,  1.1070],
#         [ 2.3223,  2.6317,  2.4725, -2.7731, -0.7657, -0.2770,  1.4095, -0.4006,
#          -0.3838,  0.2478],
#         [ 2.2674,  3.6699,  3.2015, -2.8907, -0.4718, -0.0401,  2.4924, -1.0983,
#          -0.1561,  1.3748],
#         [ 2.1889,  2.7532,  2.2579, -2.3674, -0.4236, -0.2068,  0.9079, -0.2047,
#          -0.6558,  0.5124]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([3.4315, 2.6317, 3.6699, 2.7532], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([3.4315, 2.6317, 3.6699, 2.7532], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.4452,  2.5652,  2.4126, -2.6499, -0.6569, -0.6113,  0.7690, -0.1689,
#          -0.4416,  0.9128],
#         [ 2.3979,  2.8982,  2.4830, -2.7445, -0.1516, -0.0091,  2.0839, -1.2006,
#           0.1897,  0.6976],
#         [ 2.2926,  2.8316,  2.6836, -2.6167, -0.5382, -0.1513,  1.1880, -0.4140,
#          -0.5789,  0.5534],
#         [ 2.4606,  4.1364,  3.2559, -3.0792, -0.6100, -0.2970,  2.7667, -1.0587,
#          -0.2910,  1.5793]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.5652, 2.8982, 2.8316, 4.1364], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.5652, 2.8982, 2.8316, 4.1364], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.7338,  3.0305,  2.6122, -2.5444, -0.8351, -0.4452,  1.1703, -0.2185,
#          -0.3689,  0.9297],
#         [ 2.1350,  3.2393,  2.8373, -3.4235,  0.0182, -0.2533,  1.7026, -1.2750,
#          -0.5141,  0.7466],
#         [ 2.6711,  3.8372,  2.9503, -3.1998, -0.6652, -0.1667,  3.0743, -1.7645,
#           0.4616,  1.2591],
#         [ 2.3848,  2.3818,  2.4365, -2.3797, -0.5751, -0.2327,  0.8643,  0.1125,
#          -0.8057,  0.6305]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([3.0305, 3.2393, 3.8372, 2.4365], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 1, 2], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([3.0305, 3.2393, 3.8372, 2.4365], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 1, 2], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.1772,  3.7161,  2.4577, -3.0577, -0.1717, -0.5077,  2.0559, -1.4258,
#          -0.2145,  0.9622],
#         [ 2.1068,  2.1692,  2.6626, -2.5758, -0.6680, -0.0638,  0.7321, -0.1631,
#          -0.5436,  0.7379],
#         [ 2.7113,  3.2569,  2.5867, -2.7859, -0.2642, -0.5021,  1.8940, -0.6899,
#          -0.1186,  0.8319],
#         [ 2.7458,  3.4824,  3.0581, -2.9349, -0.4642, -0.1116,  2.0395, -0.8721,
#          -0.2588,  0.8740]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([3.7161, 2.6626, 3.2569, 3.4824], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 2, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([3.7161, 2.6626, 3.2569, 3.4824], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 2, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.4077,  4.6222,  3.3364, -3.9173, -0.1608, -0.4509,  3.4180, -2.1477,
#           0.1581,  1.5764],
#         [ 2.1577,  2.5519,  2.6465, -2.4238, -0.5458, -0.4601,  1.1130, -0.1348,
#          -0.3291,  0.6992],
#         [ 2.1888,  2.0460,  2.2343, -2.3735, -0.7863, -0.2437,  0.7435, -0.1587,
#          -0.8341,  0.5228],
#         [ 2.3521,  2.9696,  2.3573, -2.6647, -0.5038,  0.1200,  1.6131, -0.1305,
#          -0.0189,  0.6346]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([4.6222, 2.6465, 2.2343, 2.9696], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 2, 2, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([4.6222, 2.6465, 2.2343, 2.9696], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 2, 2, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.4260,  2.2624,  2.2105, -2.4986, -0.5305,  0.0403,  1.1309, -0.3266,
#          -0.1314,  0.5642],
#         [ 2.7870,  5.3187,  3.5491, -3.6695, -0.1081, -0.3829,  3.9578, -2.9338,
#           0.5728,  1.6341],
#         [ 2.1059,  2.3978,  2.0918, -2.7547, -0.6941, -0.1507,  1.1227, -0.2118,
#          -0.3793,  0.5351],
#         [ 2.0307,  2.2298,  2.5160, -1.9398, -0.5656, -0.1400,  0.4219,  0.3688,
#          -0.6681,  0.7184]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.4260, 5.3187, 2.3978, 2.5160], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([0, 1, 1, 2], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.4260, 5.3187, 2.3978, 2.5160], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([0, 1, 1, 2], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.6537,  3.7822,  3.3339, -3.0599, -0.7200, -0.4248,  2.5526, -1.6179,
#           0.4359,  1.1991],
#         [ 2.5693,  3.5277,  2.4250, -3.1035, -0.2379,  0.0314,  2.2889, -1.1513,
#          -0.2994,  1.1346],
#         [ 2.2438,  2.7562,  2.6574, -2.6190, -0.7286, -0.0682,  1.1563, -0.4785,
#          -0.5619,  0.3027],
#         [ 1.8882,  2.1452,  2.5629, -2.2570, -0.3997, -0.1853,  0.7981,  0.3419,
#          -0.4349,  0.7865]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([3.7822, 3.5277, 2.7562, 2.5629], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 1, 2], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([3.7822, 3.5277, 2.7562, 2.5629], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 1, 2], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.3657e+00,  4.3382e+00,  3.6453e+00, -3.1191e+00, -2.7005e-01,
#          -6.7814e-02,  2.3767e+00, -1.2442e+00,  1.9783e-01,  1.4207e+00],
#         [ 2.2230e+00,  2.6968e+00,  1.9467e+00, -2.5152e+00, -6.2489e-01,
#          -1.2149e-01,  1.1881e+00, -6.2652e-01, -1.1979e-01,  9.7348e-01],
#         [ 1.7918e+00,  2.2264e+00,  2.2143e+00, -2.1695e+00, -4.7558e-01,
#          -1.0046e-01,  8.2880e-01, -1.2486e-03, -6.4831e-01,  5.0068e-01],
#         [ 2.4068e+00,  2.7262e+00,  2.5158e+00, -2.5773e+00, -3.3230e-01,
#          -3.3777e-01,  1.5774e+00, -9.1612e-01,  2.5493e-02,  5.5523e-01]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([4.3382, 2.6968, 2.2264, 2.7262], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([4.3382, 2.6968, 2.2264, 2.7262], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.4001,  2.8946,  2.3187, -2.6927, -0.8208, -0.0068,  1.3115, -0.4959,
#          -0.2460,  0.9798],
#         [ 2.7864,  3.6353,  2.5645, -2.9085,  0.0561, -0.5835,  2.0744, -1.5025,
#          -0.1617,  0.9026],
#         [ 2.4940,  3.0675,  3.0021, -2.9825, -0.3585, -0.3176,  1.8226, -0.6332,
#           0.1124,  1.0819],
#         [ 1.9637,  2.9119,  2.8445, -2.7431, -0.6420, -0.1871,  1.6620, -0.4236,
#          -0.3710,  0.6876]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.8946, 3.6353, 3.0675, 2.9119], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.8946, 3.6353, 3.0675, 2.9119], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 2.2943,  2.8960,  2.7756, -2.7531, -0.6414,  0.2176,  1.2327, -0.3783,
#          -0.4233,  0.9424],
#         [ 2.2922,  3.3080,  2.7209, -2.5118, -0.1363, -0.0785,  2.8586, -1.3109,
#          -0.0806,  0.9172],
#         [ 2.9405,  3.7729,  2.8817, -3.4768, -0.2862, -0.5546,  2.0522, -1.1107,
#          -0.0242,  0.9528],
#         [ 2.2474,  2.9049,  2.4966, -2.8571, -1.0597, -0.5812,  1.0301, -0.1120,
#          -0.6364,  0.9164]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.8960, 3.3080, 3.7729, 2.9049], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 1, 1], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.8960, 3.3080, 3.7729, 2.9049], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 1, 1], device='cuda:0')
#
# ******logits*******
#  tensor([[ 1.8472e+00,  2.9636e+00,  2.2159e+00, -2.2454e+00, -5.0121e-01,
#          -1.6306e-01,  1.7086e+00, -2.6622e-01, -4.0576e-03,  6.1421e-01],
#         [ 2.9823e+00,  4.9672e+00,  3.4627e+00, -3.6690e+00,  4.2869e-02,
#          -3.1373e-01,  3.3013e+00, -2.2974e+00, -1.7366e-02,  1.5828e+00],
#         [ 2.1237e+00,  2.3278e+00,  2.6061e+00, -2.6054e+00, -8.9433e-01,
#           1.9956e-01,  1.0548e+00,  5.0714e-02, -3.6122e-01,  8.7229e-01],
#         [ 2.3856e+00,  2.0627e+00,  2.4704e+00, -2.7526e+00, -4.7746e-01,
#          -3.5776e-01,  4.6583e-01, -3.6541e-02, -4.7251e-01,  6.3528e-01]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
#
#
#
# ******logits_max*******
#  torch.return_types.max(
# values=tensor([2.9636, 4.9672, 2.6061, 2.4704], device='cuda:0',
#        grad_fn=<MaxBackward0>),
# indices=tensor([1, 1, 2, 2], device='cuda:0'))
#
#
# ***********_____***********
#  tensor([2.9636, 4.9672, 2.6061, 2.4704], device='cuda:0',
#        grad_fn=<MaxBackward0>)
#
# **********predict************
#  tensor([1, 1, 2, 2], device='cuda:0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-eb6faa2e2a6c> in <module>
#       2     batch[0], batch[1] = batch[0].to(device), batch[1].to(device)
#       3
# ----> 4     logits = model(batch[0])
#       5     #print(batch[0], "\n****************\n", batch[1])
#       6     print("\n******logits*******\n",logits)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /home/sldev1/github/TIL/Internship/ResNet_CIFAR10/resnet.py in forward(self, x)
#     115         out = self.layer3(out)
#     116         out = self.layer4(out)
# --> 117         out = self.avgpool(out)
#     118         out = torch.flatten(out, 1)
#     119         out = self.linear(out)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/pooling.py in forward(self, input)
#    1165
#    1166     def forward(self, input: Tensor) -> Tensor:
# -> 1167         return F.adaptive_avg_pool2d(input, self.output_size)
#    1168
#    1169
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py in adaptive_avg_pool2d(input, output_size)
#    1129         return handle_torch_function(adaptive_avg_pool2d, (input,), input, output_size)
#    1130     _output_size = _list_with_default(output_size, input.size())
# -> 1131     return torch._C._nn.adaptive_avg_pool2d(input, _output_size)
#    1132
#    1133
#
# KeyboardInterrupt:

# %%
data_idx = np.random.randint(len(test_dataset))
print(f"data_idx : {data_idx}\n\n")

input_img = test_dataset[0][0].unsqueeze(dim=0).to(device)
# input_img = test_dataset[data_idx][0].unsqueeze(dim=0).to(device)
# print(f"iput_img : {input_img}")
output = model(input_img)
output



x = torch.max(output, 1)
x

# torch.return_types.max(
# values=tensor([3.1417], device='cuda:0', grad_fn=<MaxBackward0>),
# indices=tensor([1], device='cuda:0'))

_, argmax = torch.max(output, 1)
print(f"_ : {_}, \nargmax : {argmax}")
# type(argmax.size())

pred = label_tags[argmax.item()]
pred
#label = label_tags[test_dataset[data_idx][1].item()]
#label


#pred = label_tags[argmax.item()]
        #test_dataset = test_dataset.numpy()
#label = label_tags[test_dataset[data_idx][1]]
# Out:
# data_idx : 2431
#
#
# _ : tensor([3.1417], device='cuda:0', grad_fn=<MaxBackward0>),
# argmax : tensor([1], device='cuda:0')
# 'Happiness'

# %%
len(test_dataset)
# Out:
# 3999

# %%
x = label_load("/home/sldev1/Project/hyeongeun_test/data/FER/val_set/annotations/")[0].split('/')
x[-1]
# Out:
# '0_exp.npy'

# %%
import cv2

columns = 6
rows = 6
fig = plt.figure(figsize=(25,25))

device = "cuda"

# inference
for i in range(1, columns*rows+1):
    data_idx = np.random.randint(4000)
    input_img = test_dataset[data_idx][0].unsqueeze(dim=0).to(device) 
    

    output = model(input_img)
    _, argmax = torch.max(output, 1)
    pred = label_tags[argmax.item()]
    #test_dataset = test_dataset.numpy()
    label = label_tags[test_dataset[data_idx][1].item()]
    
    
    x = label_load("/home/sldev1/Project/hyeongeun_test/data/FER/val_set/annotations/")[data_idx].split('/')
    x = x[-1]
    
    
    fig.add_subplot(rows, columns, i)
    if pred == label:
        plt.title(pred + ', right !!\n index : ' + str(x))
        cmap = 'Blues'
    else:
        plt.title('Predict : ' + pred + ' / Answer : ' +  label + '\n index :' + str(x))
        cmap = 'Reds'
    plot_img = test_dataset[data_idx][0][0,:,:]
    plt.imshow(plot_img, cmap=cmap)
    #plt.imshow(plot_img)
    plt.axis('off')
    
plt.show()

# %%
num = 2269
x = cv2.imread(f"/home/sldev1/Project/hyeongeun_test/data/FER/val_set/images/{num}.jpg", cv2.IMREAD_COLOR)
y = int(np.load(f"/home/sldev1/Project/hyeongeun_test/data/FER/val_set/annotations/{num}_exp.npy"))

label_tags = {
    0 : 'Neutral',
    1 : 'Happiness', #기쁨
    2 : 'Sadness', #슬픔
    3 : 'Suprise', #놀람
    4 : 'Fear', #
    5 : 'Disgust', #역겨움
    6 : 'Anger', #분노
    7 : 'Content' #만족
}

plt.title(label_tags[y])
plt.imshow(x)

# %%
import gc
import torch

gc.collect()
torch.cuda.empty_cache()

# %%
# !tensorboard --logdir=runs
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.7.0 at http://localhost:6009/ (Press CTRL+C to quit)

# %% [markdown]
# # 테스트 데이터에 대한 모델 테스트
# https://learn.microsoft.com/ko-kr/windows/ai/windows-ml/tutorials/pytorch-train-model #보류
